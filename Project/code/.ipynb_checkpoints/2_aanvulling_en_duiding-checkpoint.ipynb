# %%
import pandas as pd

# %%
new2 = pd.read_csv('data/new2.csv', index_col = 0)

# %%
new2
# Out:
#       genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan
# 0        84.0   180.0  90.0       2.0      9.0      1.0    2.0      86.0
# 1        84.0   204.0  79.0       3.0      2.0      7.0    3.0     100.0
# 2        84.0   174.0  74.0       3.0     20.0      3.0    2.0      87.0
# 3        84.0   187.0  78.0       2.0      6.0      5.0    3.0      91.0
# 4        84.0   187.0  89.0       2.0     12.0      0.0    2.0      83.0
# ...       ...     ...   ...       ...      ...      ...    ...       ...
# 8187     82.0   185.0  67.0       3.0     11.0      8.0    2.0      90.0
# 8188     82.0   183.0  72.0       2.0      1.0      5.0    4.0      88.0
# 8189     83.0   192.0  92.0       1.0     22.0      2.0    4.0      62.0
# 8190     81.0   175.0  60.0       3.0     13.0      7.0    2.0      93.0
# 8191     83.0   204.0  76.0       3.0      8.0      8.0    1.0      96.0
#
# [8192 rows x 8 columns]

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 3.2 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 kB 7.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.23.5)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (3.6.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.5.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scipy<1.10,>=1.4.1
#   Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 808.3 kB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 1.1 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (0.13.5)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 1.3 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.10.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 945.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: Pillow in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (22.0)
# Requirement already satisfied: cycler>=0.10 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.14)
# Requirement already satisfied: patsy>=0.5.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: six in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (1.4.1)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=935a4bbbf5ac63e6db197bc1063b38d61084b5b8d33affd76616f5450e6248d7
#   Stored in directory: /home/pans/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, scipy, multimethod, imagehash, visions, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.0
#     Uninstalling scipy-1.10.0:
#       Successfully uninstalled scipy-1.10.0
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 pandas-profiling-3.6.6 phik-0.12.3 scipy-1.9.3 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.0.0

# %%
#Install the below libaries before importing
# import pandas as pd
from pandas_profiling import ProfileReport

#EDA using pandas-profiling
profile = ProfileReport(pd.read_csv('data/new2.csv', index_col = 0), explorative=True)

#Saving results to a HTML file
profile.to_file("data/output.html")
# Out:
# /tmp/ipykernel_11763/125457109.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/multimethod/__init__.py:315: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   return func(*args, **kwargs)
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 356.6 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: scipy>=1.3.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (1.9.3)
# Requirement already satisfied: tqdm>=4.43.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: numpy>=1.16.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: jinja2>=2.11.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (1.5.2)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from sweetviz) (3.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.12.0 sweetviz-2.1.4

# %%
# import pandas as pd
import sweetviz as sv

#EDA using Autoviz
sweet_report = sv.analyze(pd.read_csv('data/new2.csv', index_col = 0))

#Saving results to HTML file
sweet_report.show_html('data/sweet_report.html')
# Out:
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
#                                              |      | [  0%]   00:00 -> (? left)
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.58-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 570.0 kB/s eta 0:00:0031m2.6 MB/s eta 0:00:01
# Requirement already satisfied: ipython in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (8.10.0)
# Requirement already satisfied: statsmodels in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (0.13.5)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.15.4-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 821.2 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (1.23.5)
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 296.4 kB/s eta 0:00:001m297.8 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 425.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pandas in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (1.5.2)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting panel~=0.12.6
#   Downloading panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 553.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: nltk in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (3.8.1)
# Requirement already satisfied: seaborn>=0.11.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (0.12.2)
# Collecting bokeh>=2.4.2
#   Downloading bokeh-3.0.3-py3-none-any.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 810.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 713.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: xgboost>=0.82 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (1.7.3)
# Requirement already satisfied: matplotlib>=3.3.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (3.6.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (4.4.0)
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.2-py2.py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 775.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: scikit-learn in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (1.0.1)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 664.4 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: fsspec>=0.8.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from autoviz) (2022.11.0)
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 568.2 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (2022.9.0)
# Requirement already satisfied: packaging>=16.8 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (22.0)
# Requirement already satisfied: pillow>=7.1.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (9.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (1.0.5)
# Requirement already satisfied: tornado>=5.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bokeh>=2.4.2->autoviz) (6.2)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 582.8 kB/s eta 0:00:001m758.4 kB/s eta 0:00:01
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.15.3-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 810.2 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Downloading holoviews-1.15.2-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Downloading holoviews-1.15.1-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 662.1 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Downloading holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 603.0 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 554.2 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting colorcet
#   Downloading colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 534.2 kB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.3-py2.py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 741.8 kB/s eta 0:00:001m744.3 kB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pandas->autoviz) (2022.7)
# Requirement already satisfied: tqdm>=4.48.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from panel~=0.12.6->autoviz) (4.64.1)
# Collecting markdown
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 376.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: bleach in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from panel~=0.12.6->autoviz) (4.1.0)
# Collecting bokeh>=2.4.2
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 979.2 kB/s eta 0:00:00m eta 0:00:0136m0:00:01m
# Collecting pyct>=0.4.4
#   Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Collecting setuptools<61,>=42
#   Downloading setuptools-60.10.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.0 MB/s eta 0:00:000:00:01m eta 0:00:010m
# Requirement already satisfied: requests in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from panel~=0.12.6->autoviz) (2.28.1)
# Requirement already satisfied: scipy in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from xgboost>=0.82->autoviz) (1.9.3)
# Requirement already satisfied: matplotlib-inline in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (0.1.6)
# Requirement already satisfied: decorator in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (2.14.0)
# Requirement already satisfied: backcall in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (3.0.36)
# Requirement already satisfied: traitlets>=5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (5.7.1)
# Requirement already satisfied: pickleshare in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (0.18.1)
# Requirement already satisfied: stack-data in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipython->autoviz) (4.8.0)
# Requirement already satisfied: nbconvert in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter->autoviz) (7.2.9)
# Requirement already satisfied: ipywidgets in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter->autoviz) (8.0.4)
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: ipykernel in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter->autoviz) (6.19.2)
# Requirement already satisfied: notebook in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter->autoviz) (6.5.2)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: click in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nltk->autoviz) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nltk->autoviz) (2022.10.31)
# Requirement already satisfied: joblib in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nltk->autoviz) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from statsmodels->autoviz) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.1.1)
# Requirement already satisfied: six in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pexpect>4.3->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->autoviz) (0.2.5)
# Requirement already satisfied: webencodings in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: nest-asyncio in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (1.5.6)
# Requirement already satisfied: psutil in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (7.4.1)
# Requirement already satisfied: debugpy>=1.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (23.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipywidgets->jupyter->autoviz) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from ipywidgets->jupyter->autoviz) (3.0.5)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter-console->jupyter->autoviz) (5.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (2.0.5)
# Requirement already satisfied: nbformat>=5.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (5.7.0)
# Requirement already satisfied: defusedxml in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: argon2-cffi in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.5.2)
# Requirement already satisfied: ipython-genutils in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: prometheus-client in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.14.1)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 737.5 kB/s eta 0:00:001m892.5 kB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->panel~=0.12.6->autoviz) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->panel~=0.12.6->autoviz) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->panel~=0.12.6->autoviz) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->panel~=0.12.6->autoviz) (2.0.4)
# Requirement already satisfied: asttokens in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (2.0.5)
# Requirement already satisfied: pure-eval in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: executing in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (0.8.3)
# Requirement already satisfied: entrypoints in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->autoviz) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->autoviz) (2.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: fastjsonschema in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.2.post1)
# Requirement already satisfied: attrs>=17.4.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: websocket-client in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.2.0)
# Requirement already satisfied: pycparser in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234912 sha256=f3bcd601182980da1925ac73e6cb8bd523e81cea25c5666a5db56fb933c1fed4
#   Stored in directory: /home/pans/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: xlrd, setuptools, qtpy, param, markdown, emoji, textblob, pyviz-comms, pyct, pyamg, bokeh, wordcloud, panel, colorcet, holoviews, qtconsole, jupyter-console, hvplot, jupyter, autoviz
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# Successfully installed autoviz-0.1.58 bokeh-2.4.3 colorcet-3.0.1 emoji-2.2.0 holoviews-1.14.9 hvplot-0.8.2 jupyter-1.0.0 jupyter-console-6.6.1 markdown-3.4.1 panel-0.12.7 param-1.12.3 pyamg-4.2.3 pyct-0.5.0 pyviz-comms-2.2.1 qtconsole-5.4.0 qtpy-2.3.0 setuptools-60.10.0 textblob-0.17.1 wordcloud-1.8.2.2 xlrd-2.0.1

# %%
# import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

#EDA using Autoviz
autoviz = AutoViz_Class().AutoViz('data/new2.csv', index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 import pandas as pd
# ----> 2 from autoviz.AutoViz_Class import AutoViz_Class
#       4 #EDA using Autoviz
#       5 autoviz = AutoViz_Class().AutoViz('data/new2.csv', index_col = 0)
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/autoviz/__init__.py:3
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .classify_method import data_cleaning_suggestions
#       5 if __name__ == "__main__":
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/autoviz/AutoViz_Class.py:61
#      59 from sklearn.model_selection import train_test_split
#      60 ##########################################################################################
# ---> 61 from autoviz.AutoViz_Holo import AutoViz_Holo
#      62 from autoviz.AutoViz_Utils import *
#      63 from autoviz.AutoViz_NLP import draw_word_clouds
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/autoviz/AutoViz_Holo.py:5
#       3 import pandas as pd
#       4 ############# Import from autoviz.AutoViz_Class the following libraries #######
# ----> 5 from autoviz.AutoViz_Utils import *
#       6 ##############   make sure you use: conda install -c pyviz hvplot ###############
#       7 import hvplot.pandas  # noqa
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/autoviz/AutoViz_Utils.py:61
#      59 from sklearn.model_selection import train_test_split
#      60 ######## This is where we import HoloViews related libraries  #########
# ---> 61 import hvplot.pandas
#      62 import holoviews as hv
#      63 from holoviews import opts
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/hvplot/__init__.py:64
#      61 import textwrap
#      63 import param
# ---> 64 import panel as _pn
#      65 import holoviews as _hv
#      67 from holoviews import Store, render  # noqa
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/__init__.py:1
# ----> 1 from . import layout # noqa
#       2 from . import links # noqa
#       3 from . import pane # noqa
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/layout/__init__.py:1
# ----> 1 from .accordion import Accordion # noqa
#       2 from .base import Column, ListLike, ListPanel, Panel, Row, WidgetBox # noqa
#       3 from .card import Card # noqa
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/layout/accordion.py:5
#       1 import param
#       3 from bokeh.models import Column as BkColumn, CustomJS
# ----> 5 from .base import NamedListPanel
#       6 from .card import Card
#       9 class Accordion(NamedListPanel):
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/layout/base.py:13
#      11 from ..io.model import hold
#      12 from ..io.state import state
# ---> 13 from ..reactive import Reactive
#      14 from ..util import param_name, param_reprs
#      16 _row = namedtuple("row", ["children"])
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/reactive.py:35
#      31 from .models.reactive_html import (
#      32     ReactiveHTML as _BkReactiveHTML, ReactiveHTMLParser
#      33 )
#      34 from .util import edit_readonly, escape, updating
# ---> 35 from .viewable import Layoutable, Renderable, Viewable
#      37 LinkWatcher = namedtuple("Watcher", Watcher._fields+('target', 'links', 'transformed', 'bidirectional_watcher'))
#      40 class Syncable(Renderable):
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/viewable.py:27
#      25 from .config import config, panel_extension
#      26 from .io.embed import embed_state
# ---> 27 from .io.loading import start_loading_spinner, stop_loading_spinner
#      28 from .io.model import add_to_doc, patch_cds_msg
#      29 from .io.notebook import (
#      30     ipywidget, render_mimebundle, render_model, show_embed, show_server
#      31 )
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/io/__init__.py:28
#      25     panel_logger.setLevel(config.log_level)
#      27 if 'django' in sys.modules:
# ---> 28     from . import django
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/panel/io/django.py:3
#       1 from urllib.parse import urlparse
# ----> 3 from bokeh.server.django.consumers import DocConsumer, AutoloadJsConsumer
#       5 from .resources import Resources
#       6 from .server import (
#       7     autoload_js_script, server_html_page_for_session
#       8 )
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/bokeh/server/django/__init__.py:5
#       2 from bokeh.util.dependencies import import_required
#       4 # Bokeh imports
# ----> 5 from .apps import DjangoBokehConfig
#       6 from .routing import autoload, directory, document
#       7 from .static import static_extensions
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/bokeh/server/django/apps.py:29
#      26 from django.conf import settings
#      28 # Bokeh imports
# ---> 29 from .routing import Routing, RoutingConfiguration
#      31 #-----------------------------------------------------------------------------
#      32 # Globals and constants
#      33 #-----------------------------------------------------------------------------
#      35 __all__ = (
#      36     'DjangoBokehConfig',
#      37 )
#
# File ~/miniconda3/envs/miw/lib/python3.10/site-packages/bokeh/server/django/routing.py:26
#      23 from typing import Callable, List, Union
#      25 # External imports
# ---> 26 from channels.http import AsgiHandler
#      27 from django.conf.urls import url
#      28 from django.urls.resolvers import URLPattern
#
# ModuleNotFoundError: No module named 'channels'

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-2.12.3-py2.py3-none-any.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 463.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: statsmodels in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (0.13.5)
# Collecting dash>=2.0.0
#   Downloading dash-2.8.1-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 409.7 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 240.7 kB/s eta 0:00:00m eta 0:00:010:00:10
# Requirement already satisfied: seaborn in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (0.12.2)
# Requirement already satisfied: Flask in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2.2.2)
# Requirement already satisfied: six in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (1.16.0)
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 256.0 kB/s eta 0:00:001m253.4 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting missingno<=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 218.4 kB/s eta 0:00:001m319.7 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: xlrd in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: cycler in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (0.11.0)
# Requirement already satisfied: certifi in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2022.12.7)
# Requirement already satisfied: networkx in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2.8.4)
# Requirement already satisfied: pandas in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (1.5.2)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting lz4
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 212.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting future>=0.14.0
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 382.4 kB/s eta 0:00:000:00:01m eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting xarray
#   Downloading xarray-2023.2.0-py3-none-any.whl (975 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.8/975.8 kB 539.0 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: scipy==1.9.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (1.9.3)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 310.5 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: scikit-learn in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (1.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (4.11.1)
# Collecting openpyxl
#   Downloading openpyxl-3.1.1-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 kB 309.5 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: numpy in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (1.23.5)
# Requirement already satisfied: requests in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2.28.1)
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 442.3 kB/s eta 0:00:00 kB/s eta 0:00:01
# Collecting dash-bootstrap-components<=1.3.1
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 234.9 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: matplotlib<=3.6.3 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (3.6.2)
# Requirement already satisfied: itsdangerous in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from dtale) (2.0.1)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from Flask->dtale) (2.2.2)
# Requirement already satisfied: click>=8.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from Flask->dtale) (8.0.4)
# Requirement already satisfied: Jinja2>=3.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from Flask->dtale) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from matplotlib<=3.6.3->dtale) (22.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from beautifulsoup4->dtale) (2.3.2.post1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 293.2 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pytz>=2020.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from pandas->dtale) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->dtale) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from requests->dtale) (3.4)
# Requirement already satisfied: joblib>=0.11 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from scikit-learn->dtale) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pans/miniconda3/envs/miw/lib/python3.10/site-packages (from Jinja2>=3.0->Flask->dtale) (2.1.1)
# Building wheels for collected packages: future, dash-colorscales, dash-daq
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492036 sha256=37845d3759fb844971da3167b5dc4231e2fef7a3f12cea94a0872df6d73d6cb5
#   Stored in directory: /home/pans/.cache/pip/wheels/5e/a9/47/f118e66afd12240e4662752cc22cefae5d97275623aa8ef57d
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62582 sha256=38d6d4afec2f22293a4648b85795dbf364b1400bdffd63fe5359563e47719275
#   Stored in directory: /home/pans/.cache/pip/wheels/70/6a/1f/95b2135cd2c895f0cd8b5d6d6ae7d5ed0a883580b34a31a14d
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669715 sha256=a632e33fe6b94ac36ce997cd387d1c7fec7e36fe34e3a89db649e8389dfb8635
#   Stored in directory: /home/pans/.cache/pip/wheels/75/14/1b/208d09d5e239391048bdc167759977b41ba65a3d4063aebf6b
# Successfully built future dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, tenacity, lz4, future, et-xmlfile, plotly, openpyxl, xarray, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
# Successfully installed Flask-Compress-1.13 brotli-1.0.9 dash-2.8.1 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.12.3 et-xmlfile-1.1.0 flask-ngrok-0.0.25 future-0.18.3 kaleido-0.2.1 lz4-4.3.2 missingno-0.4.2 openpyxl-3.1.1 plotly-5.13.1 squarify-0.4.3 strsimpy-0.2.1 tenacity-8.2.1 xarray-2023.2.0

# %%
import dtale
# import pandas as pd

dtale.show(pd.read_csv('data/new2.csv', index_col = 0))
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://pop-os:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
